# %%
import pandas as pd
import pyarrow as pa



# window extents
wext_one = (7.1673981838973591,47.0951027481864699)
wext_two = (7.3867370409999991,47.1906072286096219)

# square id
# 585220 Langholzli and vorholzli
# 585215 langholzli sud
# 590220 vorholzli nord

# %%
dirs = ['data_1.csv', 'data_2.csv']

# %%
cols = ['date', 'taxon.taxon_id', 'taxon.taxon_name', 'taxon.no_isfs', 'taxon_orig', 'x', 'y']

df1 = pd.read_csv("data/inprocess/data_1.csv", encoding = 'UTF-16',sep = '\t')
df2 = pd.read_csv("data/inprocess/data_2.csv", encoding = 'UTF-16',sep = '\t')

# %%
t = pd.read_csv('data/inprocess/fungi_swiss/0066767-231120084113126.csv',sep = '\t')

# %%
t.head()
# Out:
#        gbifID                            datasetKey          occurrenceID  \
# 0  4120076692  c0633ec5-19cd-4a58-b84c-ca55c2e7ae64  SWISSFUNGI-CH-903056
# 1  3120112990  c0633ec5-19cd-4a58-b84c-ca55c2e7ae64   SWISSFUNGI-CH-96898
# 2  4120080669  c0633ec5-19cd-4a58-b84c-ca55c2e7ae64  SWISSFUNGI-CH-903074
# 3  3120112991  c0633ec5-19cd-4a58-b84c-ca55c2e7ae64   SWISSFUNGI-CH-96906
# 4  4120076698  c0633ec5-19cd-4a58-b84c-ca55c2e7ae64  SWISSFUNGI-CH-903092
#
#   kingdom         phylum           class        order            family  \
# 0   Fungi  Basidiomycota  Agaricomycetes  Polyporales      Polyporaceae
# 1   Fungi  Basidiomycota  Agaricomycetes   Agaricales    Hygrophoraceae
# 2   Fungi  Basidiomycota  Agaricomycetes   Agaricales  Tricholomataceae
# 3   Fungi  Basidiomycota  Agaricomycetes   Agaricales    Hygrophoraceae
# 4   Fungi  Basidiomycota  Agaricomycetes   Agaricales    Strophariaceae
#
#         genus                species  ...   identifiedBy dateIdentified  \
# ...

# %%
t.columns
# Out:
# Index(['gbifID', 'datasetKey', 'occurrenceID', 'kingdom', 'phylum', 'class',
#        'order', 'family', 'genus', 'species', 'infraspecificEpithet',
#        'taxonRank', 'scientificName', 'verbatimScientificName',
#        'verbatimScientificNameAuthorship', 'countryCode', 'locality',
#        'stateProvince', 'occurrenceStatus', 'individualCount',
#        'publishingOrgKey', 'decimalLatitude', 'decimalLongitude',
#        'coordinateUncertaintyInMeters', 'coordinatePrecision', 'elevation',
#        'elevationAccuracy', 'depth', 'depthAccuracy', 'eventDate', 'day',
#        'month', 'year', 'taxonKey', 'speciesKey', 'basisOfRecord',
#        'institutionCode', 'collectionCode', 'catalogNumber', 'recordNumber',
#        'identifiedBy', 'dateIdentified', 'license', 'rightsHolder',
#        'recordedBy', 'typeStatus', 'establishmentMeans', 'lastInterpreted',
#        'mediaType', 'issue'],
#       dtype='object')

# %%
cols = ['kingdom', 'phylum', 'class',
       'order', 'family', 'genus', 'species', 'scientificName', 'verbatimScientificName',
      'publishingOrgKey', 'decimalLatitude', 'decimalLongitude',
       'eventDate']

# %%
masklat = (t.decimalLatitude >= 47.095)&(t.decimalLatitude <= 47.190)
masklon = (t.decimalLongitude >= 7.167)&(t.decimalLongitude <= 7.38)
maskdate = t.eventDate > '2010-01-01'

pme = t[masklat&masklon&maskdate][cols].copy()
pme.head()

# %%
pme.to_csv('data/endpipe/fungi_window_extent.csv', index=False)

# %%
pme.decimalLatitude.unique()
# Out:
# array([47.10838, 47.15324, 47.10826, 47.15335, 47.15343, 47.10845])
